# %%
# Load libraries
from sklearn.model_selection import train_test_split 
from sklearn import metrics 
import numpy as np
import pandas as pd

# %%
#importing datasets
import pandas as pd
df = pd.read_excel(r'C:\Users\shrad\Desktop\pro\GL Assignment_Online Retail.xlsx')

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
#extracting records where customers have made a transaction between 1st Dec 2010 to 31st Aug 2011
mask = (df['InvoiceDate'] > '2010-12-1') & (df['InvoiceDate'] <= '2011-8-31')
mask.head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: InvoiceDate, dtype: bool

# %%
#extracting records where customers have made transaction from the period september 2011 to december 2011
mask1 = (df['InvoiceDate'] > '2011-09-1') & (df['InvoiceDate'] <= '2011-12-1')
mask1.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: InvoiceDate, dtype: bool

# %%
#first dataset
df1= df.loc[mask]

# %%
df1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 319395    564852     82552                  WASHROOM METAL SIGN        10
# 319396    564852     21756             BATH BUILDING BLOCK WORD         3
# 319397    564852     21908        CHOCOLATE THIS WAY METAL SIGN         7
# 319398    564852     22116      METAL SIGN HIS DINNER IS SERVED        10
# 319399    564852     23091           ZINC HERB GARDEN CONTAINER         2
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 319395 2011-08-30 17:23:00       1.45     14976.0  United Kingdom
# 319396 2011-08-30 17:23:00       5.95     14976.0  United Kingdom
# 319397 2011-08-30 17:23:00       2.10     14976.0  United Kingdom
# 319398 2011-08-30 17:23:00       0.79     14976.0  United Kingdom
# 319399 2011-08-30 17:23:00       6.25     14976.0  United Kingdom
#
# [319400 rows x 8 columns]

# %%
df2= df.loc[mask1]
df2
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 320705    565080     20677                   PINK POLKADOT BOWL         8
# 320706    565080     22128           PARTY CONES CANDY ASSORTED        24
# 320707    565081     21067                                  NaN         1
# 320708    565082     22423             REGENCY CAKESTAND 3 TIER         2
# 320709    565082    15060B           FAIRY CAKE DESIGN UMBRELLA         8
# ...          ...       ...                                  ...       ...
# 516379   C579886     22197                       POPCORN HOLDER        -1
# 516380   C579886     23146       TRIPLE HOOK ANTIQUE IVORY ROSE        -1
# 516381   C579887     84946         ANTIQUE SILVER T-LIGHT GLASS        -1
# 516382   C579887     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        -1
# 516383   C579887     23490     T-LIGHT HOLDER HANGING LOVE BIRD        -3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 320705 2011-09-01 08:25:00       1.25     13509.0  United Kingdom
# 320706 2011-09-01 08:25:00       1.25     13509.0  United Kingdom
# 320707 2011-09-01 09:03:00       0.00         NaN  United Kingdom
# 320708 2011-09-01 09:15:00      12.75     13305.0  United Kingdom
# 320709 2011-09-01 09:15:00       3.75     13305.0  United Kingdom
# ...                    ...        ...         ...             ...
# 516379 2011-11-30 17:39:00       0.85     15676.0  United Kingdom
# 516380 2011-11-30 17:39:00       3.29     15676.0  United Kingdom
# 516381 2011-11-30 17:42:00       1.25     16717.0  United Kingdom
# 516382 2011-11-30 17:42:00       7.95     16717.0  United Kingdom
# 516383 2011-11-30 17:42:00       3.75     16717.0  United Kingdom
#
# [195679 rows x 8 columns]

# %%
#displaying umique customer ids
import numpy as np
uni = df1.CustomerID.unique()

# %%
uni
# Out:
# array([17850., 13047., 12583., ..., 14108., 12814., 15866.])

# %%
cols = ['CustomerID', 'target']

# %%
#creating an empty dataframe consisting of customer id and churn value 
df3 = pd.DataFrame(columns= cols)
df3.shape
# Out:
# (0, 2)

# %%
v= df2['CustomerID'].to_numpy()
len(v)
v
# Out:
# array([13509., 13509.,    nan, ..., 16717., 16717., 16717.])

# %%
len(uni)
# Out:
# 3356

# %%
#check whether every customer id from df2 i.e the dataset where customer have done transactions from the period of september 2011 to december 2011 are present in df1 or not 

num = 3356
churn =0 
ntchurn =1
#z=uni
df3['CustomerID']=uni
df3['target']=np.zeros((3356,1))
for i in range(0, num):
   # df3['CustomerID'][i]=uni[i]
    for j in range(0, len(v)):
        #if z[i]==v[j]:
        if uni[i]==v[j]:
            df3['target'][i]= ntchurn
            break
    #df3['target'][i]=churn

# %%
#displaying dataset with customer ids who made subsequent purchase or not with value of 1 and 0 respectively
df3
# Out:
#       CustomerID  target
# 0        17850.0     0.0
# 1        13047.0     1.0
# 2        12583.0     1.0
# 3        13748.0     1.0
# 4        15100.0     0.0
# ...          ...     ...
# 3351     14869.0     0.0
# 3352     14096.0     1.0
# 3353     14108.0     1.0
# 3354     12814.0     0.0
# 3355     15866.0     0.0
#
# [3356 rows x 2 columns]

# %%
a=np.zeros((3356,1))
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [0.]])

# %%
#inserting output column
df1.insert(8, 'target', '')

# %%
df1.insert(9, 'countrycode','')

# %%
for i in range(0, s):
    mask = (df1['Country'] == unic[i])
    df1['countrycode'][mask] = c[i]
# Out:
# C:\Users\shrad\AppData\Local\Temp/ipykernel_4924/315385974.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['countrycode'][mask] = c[i]
# C:\Users\shrad\anaconda3\lib\site-packages\pandas\core\generic.py:8870: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
df1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 319395    564852     82552                  WASHROOM METAL SIGN        10
# 319396    564852     21756             BATH BUILDING BLOCK WORD         3
# 319397    564852     21908        CHOCOLATE THIS WAY METAL SIGN         7
# 319398    564852     22116      METAL SIGN HIS DINNER IS SERVED        10
# 319399    564852     23091           ZINC HERB GARDEN CONTAINER         2
#
#                InvoiceDate  UnitPrice  CustomerID         Country  target  \
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom     0.0
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom     0.0
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom     0.0
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom     0.0
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom     0.0
# ...                    ...        ...         ...             ...     ...
# 319395 2011-08-30 17:23:00       1.45     14976.0  United Kingdom     1.0
# 319396 2011-08-30 17:23:00       5.95     14976.0  United Kingdom     1.0
# 319397 2011-08-30 17:23:00       2.10     14976.0  United Kingdom     1.0
# 319398 2011-08-30 17:23:00       0.79     14976.0  United Kingdom     1.0
# 319399 2011-08-30 17:23:00       6.25     14976.0  United Kingdom     1.0
#
#        countrycode
# 0              1.0
# 1              1.0
# 2              1.0
# 3              1.0
# 4              1.0
# ...            ...
# 319395         1.0
# 319396         1.0
# 319397         1.0
# 319398         1.0
# 319399         1.0
#
# [312757 rows x 10 columns]

# %%
for i in range(0, 3356):
    mask = (df1['CustomerID'] == df3['CustomerID'][i])
    df1['target'][mask] = df3['target'][i]

    
    
    #for j in range(0,319400):
     #   if df3['CustomerID'][i]== df1['CustomerID'][j]:
      #      df1['target'][j]=df3['target'][i]
# Out:
# C:\Users\shrad\AppData\Local\Temp/ipykernel_4924/45743508.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['target'][mask] = df3['target'][i]
# C:\Users\shrad\anaconda3\lib\site-packages\pandas\core\generic.py:8870: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
from sklearn.model_selection import train_test_split

# %%
index_names = df1[ df1['Quantity']<0].index
  
# drop these row indexes
# from dataFrame
df1.drop(index_names, inplace = True)
df1
# Out:
# C:\Users\shrad\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 319395    564852     82552                  WASHROOM METAL SIGN        10
# 319396    564852     21756             BATH BUILDING BLOCK WORD         3
# 319397    564852     21908        CHOCOLATE THIS WAY METAL SIGN         7
# 319398    564852     22116      METAL SIGN HIS DINNER IS SERVED        10
# 319399    564852     23091           ZINC HERB GARDEN CONTAINER         2
#
#                InvoiceDate  UnitPrice  CustomerID         Country target
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom    0.0
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom    0.0
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom    0.0
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom    0.0
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom    0.0
# ...                    ...        ...         ...             ...    ...
# 319395 2011-08-30 17:23:00       1.45     14976.0  United Kingdom    1.0
# 319396 2011-08-30 17:23:00       5.95     14976.0  United Kingdom    1.0
# 319397 2011-08-30 17:23:00       2.10     14976.0  United Kingdom    1.0
# 319398 2011-08-30 17:23:00       0.79     14976.0  United Kingdom    1.0
# 319399 2011-08-30 17:23:00       6.25     14976.0  United Kingdom    1.0
#
# [312757 rows x 9 columns]

# %%
#split dataset in features and target variable
feature_cols1= ['Quantity', 'UnitPrice','countrycode']
xinp = df1[feature_cols1]

# %%
xinp.info()
xinp['Quantity'] = pd.to_numeric(xinp['Quantity'])
print("after" )
xinp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 312757 entries, 0 to 319399
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Quantity   312757 non-null  int64
#  1   UnitPrice  312757 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 7.2 MB
# after
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 312757 entries, 0 to 319399
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Quantity   312757 non-null  int64
#  1   UnitPrice  312757 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 7.2 MB
# C:\Users\shrad\AppData\Local\Temp/ipykernel_4924/2815009032.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xinp['Quantity'] = pd.to_numeric(xinp['Quantity'])

# %%
xinp.info()
xinp['UnitPrice'] = pd.to_numeric(xinp['UnitPrice'])
print("after" )
xinp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 312757 entries, 0 to 319399
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Quantity   312757 non-null  int64
#  1   UnitPrice  312757 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 7.2 MB
# after
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 312757 entries, 0 to 319399
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Quantity   312757 non-null  int64
#  1   UnitPrice  312757 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 7.2 MB
# C:\Users\shrad\AppData\Local\Temp/ipykernel_4924/2953426946.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xinp['UnitPrice'] = pd.to_numeric(xinp['UnitPrice'])

# %%
df1['target'] = pd.to_numeric(df1['target'])
print("after" )
df1.info()
# Out:
# after
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 312757 entries, 0 to 319399
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    312757 non-null  object
#  1   StockCode    312757 non-null  object
#  2   Description  312344 non-null  object
#  3   Quantity     312757 non-null  int64
#  4   InvoiceDate  312757 non-null  datetime64[ns]
#  5   UnitPrice    312757 non-null  float64
#  6   CustomerID   225733 non-null  float64
#  7   Country      312757 non-null  object
#  8   target       225733 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 23.9+ MB
# C:\Users\shrad\AppData\Local\Temp/ipykernel_4924/4012438570.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['target'] = pd.to_numeric(df1['target'])

# %%
y = df1['target'].to_numpy()
y.dtype
y = y.astype(int)
y.dtype
# Out:
# dtype('int32')

# %%
#displaying umique customer ids
import numpy as np
unic = df1.Country.unique()
unic
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Finland',
#        'Austria', 'Bahrain', 'Israel', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta'], dtype=object)

# %%
s=unic.shape[0]
c = np.zeros((s,1))
for i in range(0, s):
    c[i]=i+1

# %%
c[4]
# Out:
# array([5.])

# %%
x_train, x_test, y_train, y_test =train_test_split(xinp,y, test_size=0.25,  random_state=0)

# %%
from sklearn.linear_model import LogisticRegression


logreg = LogisticRegression()

# fit the model with data
logreg.fit(x_train,y_train)


y_pred=logreg.predict(x_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred)*100)
print("Precision:",metrics.precision_score(y_test, y_pred, average='macro')*100)
print("Recall:",metrics.recall_score(y_test, y_pred,average='macro')*100)
print("f1 score:", metrics.f1_score(y_test,y_pred, average='macro')*100)
# Out:
# Accuracy: 57.35105097231725
# Precision: 75.73299346220827
# Recall: 33.52778861112144
# f1 score: 24.734504818343005

# %%
from sklearn import svm

#Create a svm Classifier
svm1 = svm.SVC(kernel='rbf') # Linear Kernel

#Train the model using the training sets
svm1.fit(x_train2, y_train2)

#Predict the response for test dataset
y_pred2 = svm1.predict(x_test2)

print("Accuracy:",metrics.accuracy_score(y_test2, y_pred2)*100)
